# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import scipy as sp

# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# DATA LOADING and Exploration |Cleaning

# %% [markdown]
# Load a EXCEL file then creating a dataframe

# %%
df=pd.read_excel("/content/drive/MyDrive/Colab Notebooks/amazon.csv.xlsx")

# %% [markdown]
# Set the option to show maximum columns

# %%
pd.set_option('display.max_columns',None)

# %% [markdown]
# get a sneak peek of data

# %%
df.head(5)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# 1         ₹349                 43%      4       43,994
# 2       ₹1,899                 90%    3.9        7,928
# 3         ₹699                 53%    4.2       94,363
# 4         ₹399                 61%    4.2       16,905
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# 2  【 Fast Charger& Data Sync】-With built-in safet...
# 3  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3  Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4  rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2  R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# 3  R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# 4  R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  A Good Braided Cable for Your Type C Device,Go...
# 2  Good speed for earlier versions,Good Product,W...
# 3  Good product,Good one,Nice,Really nice product...
# 4  As good as original,Decent,Good one for second...
#
#                                       review_content  \
# 0  Looks durable Charging is fine tooNo complains...
# 1  I ordered this cable to connect my phone to An...
# 2  Not quite durable and sturdy,https://m.media-a...
# 3  Good product,long wire,Charges good,Nice,I bou...
# 4  Bought this instead of original apple, does th...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/W/WEBP_40237...
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
# 3  https://m.media-amazon.com/images/I/41V5FtEWPk...
# 4  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...
# 3  https://www.amazon.in/Deuce-300-Resistant-Tang...
# 4  https://www.amazon.in/Portronics-Konnect-POR-1...

# %% [markdown]
# let's see the column names

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %% [markdown]
# Let's have a look on the shape of the dataset

# %%
print(f"The Numberof Rows are{df.shape[0]},and columns are {df.shape[1]}.")
# Out:
# The Numberof Rows are1465,and columns are 16.

# %% [markdown]
# Let's have a look on the columns and their data types using detailed info function

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
#  15  product_link         1465 non-null   object
# dtypes: object(16)
# memory usage: 183.3+ KB

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %% [markdown]
# changing data type of columns from object to float

# %%
df['discounted_price'] = df['discounted_price'].str.replace('₹', '').str.replace(',', '').astype('float64')

# %%
df['discount_percentage']=df['discount_percentage'].str.replace('%','').astype('float64')/100

# %%
df['rating'].value_counts()
# Out:
# rating
# 4.1    244
# 4.3    230
# 4.2    228
# 4      181
# 3.9    123
# 4.4    123
# 3.8     86
# 4.5     75
# 3.7     42
# 3.6     35
# 3.5     26
# 4.6     17
# 3.3     16
# 3.4     10
# 4.7      6
# 3        4
# 3.1      4
# 5        3
# 4.8      3
# 3.2      2
# 2.8      2
# 2.3      1
# |        1
# 2        1
# 2.6      1
# 2.9      1
# Name: count, dtype: int64

# %%
df.query('rating=="|"')
# Out:
#       product_id                                       product_name  \
# 1279  B08L12N5H1  Eureka Forbes car Vac 100 Watts Powerful Sucti...
#
#                                                category  discounted_price  \
# 1279  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...            2099.0
#
#      actual_price  discount_percentage rating rating_count  \
# 1279       ₹2,499                 0.16      |          992
#
#                                           about_product  \
# 1279  No Installation is provided for this product|1...
#
#                                                 user_id  \
# 1279  AGTDSNT2FKVYEPDPXAA673AIS44A,AER2XFSWNN4LAUCJ5...
#
#                                               user_name  \
# 1279  Divya,Dr Nefario,Deekshith,Preeti,Prasanth R,P...
#
#                                               review_id  \
# 1279  R2KKTKM4M9RDVJ,R1O692MZOBTE79,R2WRSEWL56SOS4,R...
#
#                                            review_title  \
# 1279  Decent product,doesn't pick up sand,Ok ok,Must...
#
#                                          review_content  \
# 1279  Does the job well,doesn't work on sand. though...
#
#                                                img_link  \
# 1279  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                            product_link
# 1279  https://www.amazon.in/Eureka-Forbes-Vacuum-Cle...

# %% [markdown]
# i got this product rating on amazon by searching the provied product_id

# %%
df['rating']=df['rating'].str.replace('|','3.9').astype('float64')

# %%
df['rating_count']=df['rating_count'].str.replace(',','').astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1 non-null      float64
#  7   rating_count         1137 non-null   float64
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
#  15  product_link         1465 non-null   object
# dtypes: float64(4), object(12)
# memory usage: 183.3+ KB

# %% [markdown]
# Descriptive Statistics

# %%
df.describe()
# Out:
#        discounted_price  discount_percentage  rating   rating_count
# count       1465.000000          1465.000000     1.0    1137.000000
# mean        3125.310874             0.476915     3.9   23441.387863
# std         6944.304394             0.216359     NaN   47259.789354
# min           39.000000             0.000000     3.9    1001.000000
# 25%          325.000000             0.320000     3.9    3231.000000
# 50%          799.000000             0.500000     3.9    9344.000000
# 75%         1999.000000             0.630000     3.9   22375.000000
# max        77990.000000             0.940000     3.9  426973.000000

# %% [markdown]
# Observation Set 2

# %% [markdown]
# Dealing with the missing values

# %% [markdown]
# Missing Values

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# rating                 1464
# rating_count            328
# product_id                0
# product_name              0
# discounted_price          0
# category                  0
# discount_percentage       0
# actual_price              0
# about_product             0
# user_id                   0
# user_name                 0
# review_id                 0
# review_title              0
# review_content            0
# img_link                  0
# product_link              0
# dtype: int64

# %%
#Find missing values percentage in the data
round(df.isnull().sum()/len(df)*100,2).sort_values(ascending=False)
# Out:
# rating                 99.93
# rating_count           22.39
# product_id              0.00
# product_name            0.00
# discounted_price        0.00
# category                0.00
# discount_percentage     0.00
# actual_price            0.00
# about_product           0.00
# user_id                 0.00
# user_name               0.00
# review_id               0.00
# review_title            0.00
# review_content          0.00
# img_link                0.00
# product_link            0.00
# dtype: float64

# %%
#find the total number of missing values
df.isnull().sum().sum()
# Out:
# np.int64(1792)

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# Let's plot the missing values

# %%
#make a figure size
plt.figure(figsize=(22,10))
#plot the null values in each column
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# Figure-1:Heatmap of Missing Values

# %% [markdown]
#  Let's plot the missing values by percentage

# %%
#make figure size
plt.figure(figsize=(22,10))
#plot the null values by their percentage in each column
missing_percentage=df.isnull().sum()/len(df)*100
missing_percentage.plot(kind='bar')
#add the labels
plt.xlabel('columns')
plt.ylabel('perentage')
plt.title('percentage of missing values in each column')
# Out:
# Text(0.5, 1.0, 'percentage of missing values in each column')

# %% [markdown]
# this is a percentage null values plot

# %% [markdown]
# We are only viewing the rows where there are null values in the column

# %%
df[df['rating_count'].isnull()].head(7)
# Out:
#     product_id                                       product_name  \
# 20  B09C6HXFC1  Duracell USB Lightning Apple Certified (Mfi) B...
# 28  B09W5XR9RT  Duracell USB C To Lightning Apple Certified (M...
# 32  B08QSC1XY8  Zoul USB C 60W Fast Charging 3A 6ft/2M Long Ty...
# 33  B008FWZGSG  Samsung Original Type C to C Cable - 3.28 Feet...
# 37  B09RZS1NQT  Sounce 65W OnePlus Dash Warp Charge Cable, 6.5...
# 39  B09C6HWG18  Duracell Type C To Type C 5A (100W) Braided Sy...
# 48  B09L8DSSFH  7SEVEN® Compatible for Samsung Smart 4K Ultra ...
#
#                                              category  discounted_price  \
# 20  Computers&Accessories|Accessories&Peripherals|...             970.0
# 28  Computers&Accessories|Accessories&Peripherals|...             970.0
# 32  Computers&Accessories|Accessories&Peripherals|...             389.0
# 33  Computers&Accessories|Accessories&Peripherals|...             599.0
# 37  Computers&Accessories|Accessories&Peripherals|...             199.0
# 39  Computers&Accessories|Accessories&Peripherals|...             970.0
# 48  Electronics|HomeTheater,TV&Video|Accessories|R...             399.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 20       ₹1,799                 0.46     NaN           NaN
# 28       ₹1,999                 0.51     NaN           NaN
# 32       ₹1,099                 0.65     NaN           NaN
# 33         ₹599                 0.00     NaN           NaN
# 37         ₹999                 0.80     NaN           NaN
# 39       ₹1,999                 0.51     NaN           NaN
# 48         ₹999                 0.60     NaN           NaN
#
#                                         about_product  \
# 20  Supports Ios Devices With Max Output Up To 2.4...
# 28  1.2M Tangle Free durable tough braiding sync &...
# 32  {3A/QC 3.0 FAST CHARGING and DATA SYNC} : This...
# 33  USB Type-C to Type-C cable with universal comp...
# 37  [USB C To USB C Cord 1M] With This 1 Meter USB...
# 39  Up To 10,000+ Bend And 10,000+ Plugging And Un...
# 48  1. 7SEVEN Compatible remote suitable for all O...
#
#                                               user_id  \
# 20  AFNYIBWKJLJQKY4BGK77ZOTVMORA,AFCTNNMP2LZLY5466...
# 28  AHZWJCVEIEI76H2VGMUSN5D735IQ,AH2DFUHFTG4CKQFVG...
# 32  AHMKXORT3VNMB75C3EUBYMFYELFQ,AEKJRELVNMICYPOYT...
# 33  AEQWVGESA7TDGK7KZ4DAJQGYH32A,AECGAMNNIMW5QOPOB...
# 37  AHUH7OYN3LAUATF5EGA575WCDI6A,AFQRX6TAM6CHKARXI...
# 39  AHRUMHBZ7IAQPLH4W5Y3A6HLQFVA,AGSJW5TCLJEKW4HAJ...
# 48  AH5G2FWQ6AJBXK2IDCA22BNQTT2A,AEEV73PQDYYMSQSW4...
#
#                                             user_name  \
# 20  Prasannavijayaraghavan G.,Preet Sikka,Theeban ...
# 28  Amazon Customer,Govind Gujarathi,Vihari,shalem...
# 32  Pratyush Pahuja,Thiyagarajan,yeses,Amazon Cust...
# 33  Verified Buyer,Avishek Majumdar,Drowna roy,mah...
# 37  Anmol,Vani,Tejas Jha,Rishabh Gupta,Nik,Harsha,...
# 39  Koushal K Jain,Mathew Jibin,Jeevan,Hemanth J.,...
# 48  MONTY,Qais Makani,Rajat Shuvra Roy,Amith PJ,Dh...
#
#                                             review_id  \
# 20  R12D1BZF9MU8TN,R32MNCWO5LGFCG,RZU3UK8OZKD6X,R3...
# 28  R1Y30KU04V3QF4,RK3DSUGKIZT8Z,R3BIG7J6V2JZTU,R1...
# 32  R2S0AYWUV349HP,R35OW9CYQNAYHY,R3B3DDF1D5NULK,R...
# 33  R2Z9ENI1BK4EAB,R2JTBG4GO7WPMG,R3GKCN4UH999M8,R...
# 37  RW294SCHB5QTK,R24AGC1O5RVWYI,R3NT7AA2V3I2FB,R2...
# 39  R32JZC43P990BL,R3H7SAJ305WZL4,R37X6NTSTYLVQA,R...
# 48  RVEWH0LAEO3NH,R3E42NTD6HXN1Q,R3IC0VLPIDBPTY,R1...
#
#                                          review_title  \
# 20  Good cable for car,Good substitute for orginal...
# 28  Very good product.,Using as a spare cable in c...
# 32  Great Cable, Charging Speeds Could Be Better,G...
# 33  Good,Genuine product,Not first charge this cab...
# 37  Worth it!,Good one,Robust and effective.,Good,...
# 39  Product is as expected,Cable has problem with ...
# 48  Overall Good,Works well. Will comment on durab...
#
#                                        review_content  \
# 20  I trust this product! Works well with car play...
# 28  Fast charging.,Cable seems to be of good quali...
# 32  Not charging as fast as I'd have expected. May...
# 33  Buy it,Received in good condition and is worki...
# 37  It does the job really well. No complaints reg...
# 39  Same type is available in half prize other mak...
# 48  Overall replacement of original samsung remote...
#
#                                              img_link  \
# 20  https://m.media-amazon.com/images/W/WEBP_40237...
# 28  https://m.media-amazon.com/images/W/WEBP_40237...
# 32  https://m.media-amazon.com/images/I/419QKVTxaS...
# 33  https://m.media-amazon.com/images/W/WEBP_40237...
# 37  https://m.media-amazon.com/images/W/WEBP_40237...
# 39  https://m.media-amazon.com/images/W/WEBP_40237...
# 48  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                          product_link
# 20  https://www.amazon.in/DURACELL-Lightning-Certi...
# 28  https://www.amazon.in/Duracell-Lightning-Certi...
# 32  https://www.amazon.in/Charging-Braided-Charger...
# 33  https://www.amazon.in/Samsung-Original-Type-Ca...
# 37  https://www.amazon.in/Sounce-Type-C-Compatible...
# 39  https://www.amazon.in/DURACELL-Type-C-braided-...
# 48  https://www.amazon.in/7SEVENTM-Compatible-Repl...

# %%
#imput missing values
df['rating_count']=df.rating_count.fillna(value=df['rating_count'].median())

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# rating                 1464
# product_id                0
# category                  0
# product_name              0
# discounted_price          0
# actual_price              0
# discount_percentage       0
# rating_count              0
# about_product             0
# user_id                   0
# user_name                 0
# review_id                 0
# review_title              0
# review_content            0
# img_link                  0
# product_link              0
# dtype: int64

# %%
#find duplicate
df.duplicated().any()
# Out:
# np.False_

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
any_duplicate=df.duplicated(subset=['product_id','product_name','category','discounted_price','actual_price','discount_percentage','rating','rating_count','about_product','user_id','user_name','review_id','review_title','review_content','img_link','product_link']).any()

# %%
any_duplicate
# Out:
# np.False_

# %% [markdown]
# hencee the duplicate found

# %% [markdown]
# DATA Visualization

# %% [markdown]
# Scatter plot

# %%
#plot actual_price vs.rating
plt.scatter(df['actual_price'],df['rating'])
plt.xlabel('Actual_price')
plt.ylabel('Rating')
plt.title('Actual_price vs.Rating')
plt.show()

# %%
#dont show warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# histogram

# %%
plt.hist(df['actual_price'])
# Out:
# (array([635., 164., 155., 139.,  83.,  70.,  62.,  59.,  52.,  46.]),
#  array([  0. ,  44.8,  89.6, 134.4, 179.2, 224. , 268.8, 313.6, 358.4,
#         403.2, 448. ]),
#  <BarContainer object of 10 artists>)

# %%
from pandas.core.arrays.categorical import factorize_from_iterable
from sklearn.preprocessing import LabelEncoder
#iabel encode categorical variables
le_product_id=LabelEncoder()
le_category=LabelEncoder()
le_review_id=LabelEncoder()
le_review_content=LabelEncoder()
le_product_name=LabelEncoder()
le_user_id=LabelEncoder()
le_about_product=LabelEncoder()
le_user_name=LabelEncoder()
le_review_title=LabelEncoder()
le_img_link=LabelEncoder()
le_product_link=LabelEncoder()
df['product_id']=le_product_id.fit_transform(df['product_id'])
df['category']=le_category.fit_transform(df['category'])
df['review_id']=le_review_id.fit_transform(df['review_id'])
df['review_content']=le_review_content.fit_transform(df['review_content'])
df['product_name']=le_product_name.fit_transform(df['product_name'])
df['user_name']=le_user_name.fit_transform(df['user_name'])
df['about_product']=le_about_product.fit_transform(df['about_product'])
df['user_id']=le_user_id.fit_transform(df['user_id'])
df['review_title']=le_review_title.fit_transform(df['review_title'])
df['img_link']=le_img_link.fit_transform(df['img_link'])
df['product_link']=le_product_link.fit_transform(df['product_link'])

# %% [markdown]
# Heatmap

# %%
df['actual_price'] = df['actual_price'].str.replace('₹', '').str.replace(',', '').astype('float64')

# %%
#plot correlations between variable
correlation_matrix=df.corr()
sns.heatmap(correlation_matrix,annot=True)
plt.show()

# %% [markdown]
# correlation analysis

# %%
#calculate pearson correlation coefficient
correlation_matrix=df.corr()
#print the correlation matrix
print(correlation_matrix)
#create a heatmap to visulation the correlations
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm')
plt.title('correlation matrix(pearson)')
plt.show()
#calculate spearman correlation coefficients(for n on- linear relationships)
spearman_correlation=df.corr(method='spearman')
#print the spearman correlation matrix
print(spearman_correlation)
#creat a heatmap to visualize the spearman correlations
sns.heatmap(spearman_correlation,annot=True,cmap='coolwarm')
plt.title('correlation matrix(spearman)')
plt.show()
# Out:
#                      product_id  product_name  category  discounted_price  \
# product_id             1.000000      0.084089 -0.012565          0.206448
# product_name           0.084089      1.000000 -0.103778          0.090665
# category              -0.012565     -0.103778  1.000000          0.119365
# discounted_price       0.206448      0.090665  0.119365          1.000000
# actual_price           0.246733      0.078567  0.122451          0.961915
# discount_percentage    0.289514      0.101913 -0.314465         -0.242412
# rating                      NaN           NaN       NaN               NaN
# rating_count          -0.140878      0.085498 -0.092422         -0.036686
# about_product          0.041404      0.158263 -0.038753          0.052618
# user_id                0.065688     -0.024093  0.012707          0.041731
# user_name              0.016145      0.024598  0.037822         -0.063069
# review_id             -0.024282      0.013492  0.014015         -0.049757
# review_title           0.007650     -0.060594  0.004712         -0.020981
# review_content        -0.046273     -0.018505 -0.012107         -0.015904
# img_link              -0.078803     -0.060858  0.038850          0.018917
# product_link           0.096205      0.823725 -0.067710          0.110186
#
#                      actual_price  discount_percentage  rating  rating_count  \
# product_id               0.246733             0.289514     NaN     -0.140878
# product_name             0.078567             0.101913     NaN      0.085498
# category                 0.122451            -0.314465     NaN     -0.092422
# discounted_price         0.961915            -0.242412     NaN     -0.036686
# actual_price             1.000000            -0.118098     NaN     -0.044213
# discount_percentage     -0.118098             1.000000     NaN      0.023145
# rating                        NaN                  NaN     NaN           NaN
# rating_count            -0.044213             0.023145     NaN      1.000000
# about_product            0.048529             0.060846     NaN     -0.028468
# user_id                  0.041501             0.008288     NaN     -0.093994
# user_name               -0.049567             0.064618     NaN      0.058930
# review_id               -0.045640             0.022442     NaN     -0.039640
# review_title             0.004521             0.076043     NaN     -0.084918
# review_content          -0.013948             0.005993     NaN     -0.025654
# img_link                 0.020080            -0.011701     NaN     -0.100624
# product_link             0.099286             0.074548     NaN     -0.004096
#
#                      about_product   user_id  user_name  review_id  \
# product_id                0.041404  0.065688   0.016145  -0.024282
# product_name              0.158263 -0.024093   0.024598   0.013492
# category                 -0.038753  0.012707   0.037822   0.014015
# discounted_price          0.052618  0.041731  -0.063069  -0.049757
# actual_price              0.048529  0.041501  -0.049567  -0.045640
# discount_percentage       0.060846  0.008288   0.064618   0.022442
# rating                         NaN       NaN        NaN        NaN
# rating_count             -0.028468 -0.093994   0.058930  -0.039640
# about_product             1.000000 -0.001946  -0.004547   0.019690
# user_id                  -0.001946  1.000000  -0.051368   0.001685
# user_name                -0.004547 -0.051368   1.000000  -0.009057
# review_id                 0.019690  0.001685  -0.009057   1.000000
# review_title             -0.015824  0.039035  -0.038880  -0.034569
# review_content           -0.024567  0.031295   0.002433   0.016665
# img_link                  0.030874 -0.014114  -0.038779   0.005422
# product_link              0.147208 -0.008662   0.026996   0.014423
#
#                      review_title  review_content  img_link  product_link
# product_id               0.007650       -0.046273 -0.078803      0.096205
# product_name            -0.060594       -0.018505 -0.060858      0.823725
# category                 0.004712       -0.012107  0.038850     -0.067710
# discounted_price        -0.020981       -0.015904  0.018917      0.110186
# actual_price             0.004521       -0.013948  0.020080      0.099286
# discount_percentage      0.076043        0.005993 -0.011701      0.074548
# rating                        NaN             NaN       NaN           NaN
# rating_count            -0.084918       -0.025654 -0.100624     -0.004096
# about_product           -0.015824       -0.024567  0.030874      0.147208
# user_id                  0.039035        0.031295 -0.014114     -0.008662
# user_name               -0.038880        0.002433 -0.038779      0.026996
# review_id               -0.034569        0.016665  0.005422      0.014423
# review_title             1.000000        0.201131 -0.012056     -0.006080
# review_content           0.201131        1.000000 -0.020283     -0.038574
# img_link                -0.012056       -0.020283  1.000000     -0.043935
# product_link            -0.006080       -0.038574 -0.043935      1.000000
#                      product_id  product_name  category  discounted_price  \
# product_id             1.000000      0.083112 -0.013553          0.146237
# product_name           0.083112      1.000000 -0.106193          0.056597
# category              -0.013553     -0.106193  1.000000          0.360733
# discounted_price       0.146237      0.056597  0.360733          1.000000
# actual_price           0.269064      0.105719  0.277291          0.932787
# discount_percentage    0.271879      0.106467 -0.322090         -0.372991
# rating                      NaN           NaN       NaN               NaN
# rating_count          -0.121237      0.091148 -0.164111          0.080137
# about_product          0.041118      0.157675 -0.048319         -0.056144
# user_id                0.065228     -0.023810  0.015389          0.079048
# user_name              0.016859      0.024479  0.038735         -0.018599
# review_id             -0.024644      0.015269  0.016119         -0.048420
# review_title           0.007415     -0.060779  0.009407         -0.018665
# review_content        -0.045763     -0.017671 -0.013519         -0.053281
# img_link              -0.078258     -0.060212  0.042158         -0.021097
# product_link           0.095734      0.823655 -0.065789          0.071049
#
#                      actual_price  discount_percentage  rating  rating_count  \
# product_id               0.269064             0.271879     NaN     -0.121237
# product_name             0.105719             0.106467     NaN      0.091148
# category                 0.277291            -0.322090     NaN     -0.164111
# discounted_price         0.932787            -0.372991     NaN      0.080137
# actual_price             1.000000            -0.066363     NaN      0.076876
# discount_percentage     -0.066363             1.000000     NaN      0.004593
# rating                        NaN                  NaN     NaN           NaN
# rating_count             0.076876             0.004593     NaN      1.000000
# about_product           -0.029216             0.061906     NaN     -0.115667
# user_id                  0.086375             0.005825     NaN     -0.050645
# user_name               -0.001395             0.066214     NaN      0.015799
# review_id               -0.045914             0.012696     NaN     -0.026393
# review_title             0.004687             0.075222     NaN     -0.022245
# review_content          -0.058924             0.012542     NaN     -0.033168
# img_link                -0.018511            -0.010185     NaN     -0.086385
# product_link             0.111965             0.074625     NaN      0.009942
#
#                      about_product   user_id  user_name  review_id  \
# product_id                0.041118  0.065228   0.016859  -0.024644
# product_name              0.157675 -0.023810   0.024479   0.015269
# category                 -0.048319  0.015389   0.038735   0.016119
# discounted_price         -0.056144  0.079048  -0.018599  -0.048420
# actual_price             -0.029216  0.086375  -0.001395  -0.045914
# discount_percentage       0.061906  0.005825   0.066214   0.012696
# rating                         NaN       NaN        NaN        NaN
# rating_count             -0.115667 -0.050645   0.015799  -0.026393
# about_product             1.000000 -0.001770  -0.004390   0.020765
# user_id                  -0.001770  1.000000  -0.051860   0.001674
# user_name                -0.004390 -0.051860   1.000000  -0.009772
# review_id                 0.020765  0.001674  -0.009772   1.000000
# review_title             -0.015792  0.038260  -0.038420  -0.035109
# review_content           -0.025319  0.032042   0.002172   0.017536
# img_link                  0.030514 -0.014201  -0.039575   0.005354
# product_link              0.146951 -0.008345   0.026876   0.015516
#
#                      review_title  review_content  img_link  product_link
# product_id               0.007415       -0.045763 -0.078258      0.095734
# product_name            -0.060779       -0.017671 -0.060212      0.823655
# category                 0.009407       -0.013519  0.042158     -0.065789
# discounted_price        -0.018665       -0.053281 -0.021097      0.071049
# actual_price             0.004687       -0.058924 -0.018511      0.111965
# discount_percentage      0.075222        0.012542 -0.010185      0.074625
# rating                        NaN             NaN       NaN           NaN
# rating_count            -0.022245       -0.033168 -0.086385      0.009942
# about_product           -0.015792       -0.025319  0.030514      0.146951
# user_id                  0.038260        0.032042 -0.014201     -0.008345
# user_name               -0.038420        0.002172 -0.039575      0.026876
# review_id               -0.035109        0.017536  0.005354      0.015516
# review_title             1.000000        0.203353 -0.012142     -0.006416
# review_content           0.203353        1.000000 -0.020711     -0.038634
# img_link                -0.012142       -0.020711  1.000000     -0.043347
# product_link            -0.006416       -0.038634 -0.043347      1.000000

# %%
#calculate correlation coefficient between product price and sales
correlation_coefficient=np.corrcoef(df['actual_price'],df['rating'])[0,1]
#print correlation coefficient
print(correlation_coefficient)
# Out:
# nan

# %% [markdown]
# grouping the aggregation

# %%
#calculate mean sales by product category
grouped_df=df.groupby('category')['rating'].mean()
print(grouped_df)
# Out:
# category
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 206   NaN
# 207   NaN
# 208   NaN
# 209   NaN
# 210   NaN
# Name: rating, Length: 211, dtype: float64

# %% [markdown]
# calculate summary statistics for groups

# %%
#mean rating category
mean_sales_by_category=df.groupby('category')['rating'].mean()
print(mean_sales_by_category)
#median rating by review content
median_sales_by_age=df.groupby('review_content')['rating'].median()
print(median_sales_by_age)
#standard deviation of actual_price by product_name
std_price_by_brand=df.groupby('product_name')['actual_price'].std()
print(std_price_by_brand)
# Out:
# category
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 206   NaN
# 207   NaN
# 208   NaN
# 209   NaN
# 210   NaN
# Name: rating, Length: 211, dtype: float64
# review_content
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1207   NaN
# 1208   NaN
# 1209   NaN
# 1210   NaN
# 1211   NaN
# Name: rating, Length: 1212, dtype: float64
# product_name
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1332    NaN
# 1333    NaN
# 1334    NaN
# 1335    NaN
# 1336    0.0
# Name: actual_price, Length: 1337, dtype: float64

# %% [markdown]
# create pivot tables

# %%
from pandas.core.reshape.api import pivot_table
#pivot  table of rating by categoy and custome location
pivot_table=df.pivot_table(values='rating',index='category',columns='product_link',aggfunc='mean')
print(pivot_table)
# Out:
# product_link  435
# category
# 187           3.9

# %% [markdown]
# statical tests

# %%
import scipy.stats as stats
#conduct t_test to compare rating b/w two categories
t_statistic,p_value=stats.ttest_ind(df[df['category']=='electronics']['rating'],df[df['category']=='clothing']['rating'])
#print t_statistic and p_value
print(t_statistic,p_value)
# Out:
# nan nan

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   int64
#  1   product_name         1465 non-null   int64
#  2   category             1465 non-null   int64
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1 non-null      float64
#  7   rating_count         1465 non-null   float64
#  8   about_product        1465 non-null   int64
#  9   user_id              1465 non-null   int64
#  10  user_name            1465 non-null   int64
#  11  review_id            1465 non-null   int64
#  12  review_title         1465 non-null   int64
#  13  review_content       1465 non-null   int64
#  14  img_link             1465 non-null   int64
#  15  product_link         1465 non-null   int64
# dtypes: float64(5), int64(11)
# memory usage: 183.3 KB

# %%
#chi_square test
#creat a contigency tables
contigency_table=pd.crosstab(df['actual_price'],df['rating'])
contigency_table
# Out:
# rating        3.9
# actual_price
# 2499.0          1

# %%
#perform chi_sqare test
chi2,p,dof,expected=stats.chi2_contingency(contigency_table)
#print the results
print('chi_square statistic:',chi2)
print('p_value:,p')
print('Degrees of freedom:',dof)
print(f"Expected:\n{expected}")
# Out:
# chi_square statistic: 0.0
# p_value:,p
# Degrees of freedom: 0
# Expected:
# [[1.]]
